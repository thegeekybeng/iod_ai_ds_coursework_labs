# %% [markdown]
# <a href="https://colab.research.google.com/github/thegeekybeng/iod_ai_ds_coursework_labs/blob/Module-1-Labs/submission_andrew_yeo_iod_lab_1_2_2b_calculus_derivative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Calculus - Derivative

# %% [markdown]
# In this lab you will find the derivative of a function from first principles - as the limit of the slope of the function as the change in the input x tends to zero.

# %%
import numpy as np
import matplotlib.pyplot as plt

# get matplot to show charts inline
# %matplotlib inline

# %%
# define a function such as f(x) = x**3
def f(x):
  '''
  Return x**3
  '''
  return x**3

# %%
# test the function you defined above by simply print its value for some numbers
print('f(2) = ',f(2))
print('f(5) = ',f(5))
print('f(-3) = ',f(-3))
# Out:
# f(2) =  8
# f(5) =  125
# f(-3) =  -27

# %%
# plot f(x)
x = np.arange(-10,11,1)
y = f(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %%
# define derivative function
def derivative(x):
    # set delta (change in x) to a small value, say 0.001
    delta = 1.0/1000.0
    # define rise (the change in f(x))
    rise = (f(x+delta)-f(x))
    slope = rise/delta     # the equation for finding slope
    return slope

# %%
# test the derivative function for some values of x
print('derivative of f(2) = ', derivative(3))
print('derivative of f(-7) = ', derivative(-7))
# Out:
# derivative of f(2) =  27.009000999996147
# derivative of f(-7) =  146.9790010000338

# %%
# plot derivative of f(x)
x = np.arange(-10,11,1)
y = derivative(x)

# %%
# plot both x and derivative of f(x)
x = np.arange(-10,11,1)
y = f(x)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('x')
ax1.set_ylabel('f(x)', color=color)
ax1.plot(x, y, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(which='major', axis='both', linestyle='--')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

z = derivative(x)
color = 'tab:blue'
ax2.set_xlabel('x')
ax2.set_ylabel('derivative(x)', color=color)
ax2.plot(x, z, color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.grid(which='major', axis='both', linestyle='--')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Check the answer using sympy:

# !pip install sympy # uncomment this line if sympy has not been installed
from sympy import symbols, diff
x = symbols('x')
f = x**3
diff(f,x)
# Out:
# 3*x**2

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2025 Institute of Data
#
#
# ---
#
#
#
# ---
